# %%
#%load Trainer.py
# !python train.py ^GSPC 10 100
# Out:
# /home/lugal/anaconda3/envs/anaver36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Episode 0/100
# Buy: $1298.35
# Sell: $1295.86 | Profit: -$2.49
# Buy: $1318.55
# Buy: $1326.65
# Sell: $1329.47 | Profit: $10.92
# Sell: $1347.97 | Profit: $21.32
# Buy: $1342.54
# Buy: $1342.90
# Sell: $1357.51 | Profit: $14.97
# Buy: $1364.17
# Buy: $1366.01
# Sell: $1373.47 | Profit: $30.57
# Buy: $1332.53
# Sell: $1314.76 | Profit: -$49.41
# Sell: $1330.31 | Profit: -$35.70
# 2018-08-03 03:27:19.248316: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# Buy: $1278.94
# Sell: $1255.27 | Profit: -$77.26
# Sell: $1245.86 | Profit: -$33.08
# Buy: $1267.65
# ...
